# %% [markdown]
# # Due Friday November 10, 2023 (11:59 pm)

# %% [markdown]
# # Problem 1: The Lagrange Point (5 points)

# %% [markdown]
# ![L1.png](data:image/png;base64,...)

# %% [markdown]
# The Lagrange point between the Earth and the Moon is given by  (see the Figure above)
# \begin{equation}
# {GM\over r^2} - {Gm\over(R-r)^2} = \omega^2 r,
# \end{equation}
# where $M$ and $m$ are the Earth and Moon masses, $G$ is Newton's
# gravitational constant, and $\omega$ is the angular velocity of both the
# Moon and the satellite.
#
#
# \begin{align*}
# G &= 6.674\times10^{-11}\,\mathrm{m}^3\mathrm{kg}^{-1}\mathrm{s}^{-2}, \\
# M &= 5.974\times10^{24}\,\mathrm{kg}, \\
# m &= 7.348\times10^{22}\,\mathrm{kg}, \\
# R &= 3.844\times10^8\,\mathrm{m}, \\
# \omega &= 2.662\times10^{-6}\,\mathrm{s}^{-1}.
# \end{align*}
#
# Greek letter: $\omega$: omega
#
#
# (a) plot $f(r) = {GM\over r^2} - {Gm\over(R-r)^2} - \omega^2 r
# $, from $r=0.1R$ to $0.9R$  (2 points)

# %%
G = 6.674e-11
M = 5.974e+24
m = 7.348e+22
R = 3.844e+8
omega = 2.662e-6

# %% [markdown]
# (b) Find $r$.  What is $r/R$?  (3 points)

# %% [markdown]
# # Problem 2:  Low-pass filter, ODE with one variable: x(t)  (10 points)
#
# ![Screen Shot 2020-11-05 at 1.19.02 PM.png](data:image/png;base64,...)

# %% [markdown]
# Consider the electronic circuit shown above. Base on Ohm's law and the capacitor law, we have
# \begin{equation}
# IR = V_\textrm{in} - V_\textrm{out}\,,\qquad
# Q = CV_\textrm{out}\,,\qquad
# I = \frac{dQ}{dt}.
# \end{equation}
#
# We obtain the differential equation for $V_\textrm{out}$
# \begin{equation}
# \frac{d V_\textrm{out}}{dt}  = {1\over RC}
#                               \bigl( V_\textrm{in} - V_\textrm{out} \bigr).
# \end{equation}
#
# (a)
# We would like to input a signal described by a square-wave with frequency 1 and amplitude 1.
#
#
# \begin{equation}
# V_\textrm{in}(t) = \begin{cases}
#                     1  & \qquad\mbox{if $\lfloor 2t \rfloor$ is even,} \\
#                     -1 & \qquad\mbox{if $\lfloor 2t \rfloor$ is odd,}
#                   \end{cases}
# \end{equation}
#
# where $\lfloor x\rfloor$ means $x$ rounded down to the next lowest integer and can be calculated using `np.floor()`.  Write a function `v_in(t)` for this.
# Make a plot for $V_\textrm{in}(t)$ for $t=0$ to $t=10$.  Hint: you might (or might not) need to write a for-loop.  (3 points)

# %% [markdown]
# (b) Solve $V_\textrm{out}(t)$ for $t=0$ to $t=10$ when $RC=0.01$, with initial
# condition $V_\textrm{out}(0)=0$.
# Plot $V_\textrm{out}(t)$  together with $V_\textrm{in}(t)$.  (4 points)

# %% [markdown]
# (c) Repeat the calculation for $RC=0.1$ and $RC=1$.  This circuit is called a low-pass filter --- what does it do?   (3 pt)

# %% [markdown]
# # Problem 3: ODEs for x(t), y(t), and z(t)  (10 points)
#
# Consider this sets of equations
# \begin{equation}
# \frac{dx}{dt} = \sigma(y-x),\qquad
# \frac{dy}{dt} = rx - y - xz,\qquad
# \frac{dz}{dt} = xy - bz,
# \end{equation}
#
# Greek letter: $\sigma$: sigma
#
# (a) Solve this set of equations for $\sigma=10$, $r=28$ and $b=8/3$, for $t=0$, to $t=50$, with initial conditions $x=0$, $y=1$, $z=0$.  (Be careful with variable names.)   (6 points)

# %% [markdown]
# (b) Plot $y(t)$. (2 points)

# %% [markdown]
# (c) Plot $z$ against $x$.  Hint: save small t step size to make your curve smooth.  (2 points)
#
# This is called the Lorenz equations and the feature you see here is called "strange attractors."
