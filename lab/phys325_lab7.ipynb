# %% [markdown]
# # Singular value decomposition for data compression
#
# Today's lab is based on this video:
# https://www.youtube.com/watch?v=H7qMMudo3e8&list=PLMrJAkhIeNNSVjnsviglFoY2nXildDCcv&index=6
#
# Fist, upload to Google Colab a photo of your choice:

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# (a) Read in the photo, convert it to black-white, and plot it using
#
# ```
# import matplotlib.pyplot as plt
# from matplotlib.image import imread
# import numpy as np
# A = imread('panda.jpg')
# A = np.mean(A, -1) # converting RGB to grayscale
# img = plt.imshow(A)
# img.set_cmap('gray')
# ```
#
# This image is now represented by a matrix $A$, whose elements correspond to the gray scale of each pixel.
#
# How many rows and columns does this matrix have? (1 point)

# %% [markdown]
# (b) Perform SVD of the matrix.  Use
# `full_matrices=False`.  How many singular values are there? (1 point)

# %% [markdown]
# (c) Plot the singular values (the output is already arranged from large to small). The x-axis is the index of the array of the singular value.
# Use log scale on y-axis and linear scale on x-axis (hint: `plt.yscale('log')`).  This is often called the ``scree plot'' due to its shape.  (1 point)

# %% [markdown]
# (d) Plot the cumulative sum of these singular values, normalized by the sum of all the singular values.  That is,
#
# $$
# \alpha = \frac{\sum_{i=0}^{r-1} \sigma_{i}}{\sum_{i=0}^{n} \sigma_{i}}
# $$
#
# plot $\alpha$ vs. $r$.  Hint: you can use `np.cumsum`.  (1 point)

# %% [markdown]
# (e) How many singular values include 50% of the sum of all the information in this image (i.e. find $r$ so that $\alpha=0.5$)?
# How about 70%? 90%? (1 point)

# %% [markdown]
# (f) Use $A = U \Sigma V^T $ to
# reconstruct the entire image using the singular values and vectors.  Hint: make sure the dimensions of $U$, $\Sigma$, $V$ are aligned.  (1 point)

# %% [markdown]
# (g)  Reconstruct the image using the first 10 singular values, 10 left  singular vectors, and 10 right singular vectors.
# (2 points)

# %% [markdown]
# (h) Repeat for the number of singular values you found in part (e), which are associated with 50%, 70%, 90% of the sum of all singular values. (1 point)

# %% [markdown]
# (i) Describe in words: How many singular values do you need to construct a reasonably good image?  How does it compare with the total number of singular values?  (1 point)
