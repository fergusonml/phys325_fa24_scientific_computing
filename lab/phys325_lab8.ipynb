# %% [markdown]
# # Problem 1: Minimizing a 2-variable function
#
# Consider this function
#
# $f(x, y) = 100 (y-x^2)^2 + (1-x)^2$
#
# Find the minimum of this function.  Please try at least 4 initial points.
# Hint: please define a python function `f(para)` and use `x = para[0]` and `y = para[1]`.  When setting the initial guess, you'll need two values.

# %% [markdown]
# # Problem 2: Linear regression & chi-square minimization
# Here we have some data with error bars

# %%
import numpy as np
x = np.array([200, 300, 400, 500, 600, 700, 800, 900])
y = np.array([5.1, 5.5, 5.9, 6.8, 7.4, 7.5, 8.6, 9.4])
sigma = 0.1 * y

# %% [markdown]
# (a) Plot y vs. x with error bars (`plt.errorbar`)

# %% [markdown]
# (b) Define a `function chi_squared(para)` within which
# `a = para[0]` and `b=para[1]`.  This function returns:
# $$
# \chi^2 = \sum_i \frac{(y_i - (a + b x_i))^2}{\sigma_i^2}
# $$

# %% [markdown]
# (c) Find the a, b value that minimizes this $\chi^2$

# %% [markdown]
# (d) What is the degree of freedom of this problem?
# What is the best-fit $\chi^2$ per degree of freedom?

# %% [markdown]
# (e) Use `numpy.polynomial.polynomial.polyfit`
# find the slope & intercept (don't forget to set w).  You should get the same answer.

# %% [markdown]
# (f) Over-plot the best fit model.

# %% [markdown]
# # Creating a document with overleaf
#
# Go to "overleaf.com", create an account, and open an "example project"
#
# ```
# \begin{equation}
# f(x) = x^2
# \end{equation}
#
# Here is how to write equation in a sentence $y=x^2$, and it's awesome.
# ```
#
# Turn on link sharing and send the link to your team members.
#
# Take a look at: [Math expressions](https://www.overleaf.com/learn/latex/Mathematical_expressions) and [Greek letters and math symbols](https://www.overleaf.com/learn/latex/List_of_Greek_letters_and_math_symbols)
